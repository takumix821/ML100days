# %% [markdown]
# ## 作業:
# 某工廠想知道兩條不同的生產線的產品不良率是否有所不同，由兩條生產線中各抽取 300 個樣本，第一組有  75 個不良品，第二組有 30 個不良品，我們可以宣稱生產線所生產出的產品不良率不相同? (以 0.05 為顯著水準)?
# (提示:透過課程投影片的步驟，需思考 𝐻_0、 𝐻_1 的寫法和範例不同唷。)

# %%
# library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns

# %%
'''
H0: p1 = p2
H1: p1 != p2
'''
# Out:
# '\nH0: p1 = p2\nH1: p1 != p2\n'

# %%
from statsmodels.stats.proportion import proportions_ztest
A = np.array([75, 30])
B = np.array([300, 300])
a = proportions_ztest(A, B, alternative = 'two-sided')

# %%
a[1] <= 0.05 # (Z score, p value)
# Out:
# True

# %%
'''
不良率不相同
'''
# Out:
# '\n不良率不相同\n'
